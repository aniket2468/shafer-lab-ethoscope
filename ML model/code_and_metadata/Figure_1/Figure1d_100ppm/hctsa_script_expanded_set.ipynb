# %%
cd hctsa-master/hctsa
startup %navigate to the hctsa directory and load the packages for hctsa

# %%
TS_Init('ethoscope_metadata_expanded_set.txt') %load the metadata file and preprocess

# %%
TS_Compute() % compute the files with hctsa

# %%
TS_Normalize('mixedSigmoid',[0.4,1.0], 'HCTSA.mat') %normalise data based on a mixed sigmoid model, with threshold of 0.4 for good time series and 1.0 for features

# %%
TS_LabelGroups('HCTSA_N.mat',{'syn_cpd_3','ddt','juglone',''diflubenzuron,'rotenone','methotrexate','diafenthiuron','fenoxycarb','DCCD','lufenuron','chlorfenapyr','thiamethoxam','tebfenozide','flonicamid','syn_cpd_2','quinuclidine_hydrochloride','indoxacarb','fluazinam','syn_cpd_5','syn_cpd_7','methoprene','permethrin','tubulin','metaflumizone','syn_cpd_12','cyenopyrafen','syn_cpd_1','syn_cpd_10','abamectin','diamide_syn_cpd','chlorantraniliprole','cyantraniliprole','cyantraniliprole','dieldrin',
                'flubendiamide','imidacloprid','pymetrozine','ryanodine','spiroindoline','tetramethrin'}) #set group labels based on keywords

# %%
TS_Classify('HCTSA_N.mat') #classify groups with a classification matrix
