# %%
cd hctsa-master/hctsa
startup %navigate to the hctsa directory and load the packages for hctsa

# %%
TS_Init('metadata_sdi_baseline_hctsa.txt') %load the metadata file and preprocess

# %%
TS_Compute()  %compute the files with hctsa

# %%
TS_Normalize('mixedSigmoid',[0.4,1.0], 'HCTSA.mat') 
# %normalise data based on a mixed sigmoid model, with threshold of 0.4 for good time series and 1.0 for features

# %%
TS_LabelGroups('HCTSA_N.mat',{'control','sdi1','sdi2','sdi3','sdi4','sdi5','sdi6','sdi7','sdi8','sdi9','sdi10',}) %set group labels based on keywords

# %%
TS_Classify()
