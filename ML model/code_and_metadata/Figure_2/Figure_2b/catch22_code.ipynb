# %%
cd hctsa-master/hctsa
startup %navigate to the hctsa directory and load the packages for hctsa

# %%
 TS_Init('all_compounds_moa_100_v2.txt','INP_mops_catch22.txt','INP_ops_catch22.txt') 
 # %load metadata for catch22

# %%
TS_Compute

# %%
TS_LabelGroups('HCTSA.mat','abamectin','diamide_syn_cpd','chlorantraniliprole','cyantraniliprole','dieldrin','flubendiamide','imidacloprid','pymetrozine','ryanodine','spiroindoline','solvent','tetramethrin') 
# %no normalisation needed here

# %%
TS_Classify()
